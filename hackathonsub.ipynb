# %%
import numpy as np 
import pandas as pd 
from sklearn import preprocessing
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.linear_model import LogisticRegression
from tqdm.auto import tqdm
from sklearn.metrics import f1_score,make_scorer,classification_report,accuracy_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.preprocessing import StandardScaler
from scipy.stats import zscore

# %%
df=pd.read_csv('Train.csv')

# %%
df
# Out:
#          V1     V2     V3  V4       V5      V6    V7  V8     V9  V10  ...  \
# 0       0.0    1.0  243.0  29   4528.0   138.0   3.0  29  201.0  0.0  ...
# 1       0.0   20.0    8.0  14   4183.0   183.0   4.0  26  156.0  0.0  ...
# 2      14.0    2.0    2.0   9   1113.0    15.0  37.0  31   78.0  1.0  ...
# 3       0.0  175.0   17.0  16   4250.0    68.0   8.0  30  152.0  0.0  ...
# 4       2.0   -1.0    1.0   3      0.0     0.0   2.0   5    6.0  1.0  ...
# ...     ...    ...    ...  ..      ...     ...   ...  ..    ...  ...  ...
# 40771   0.0    0.0    4.0   5  41928.0  1836.0   1.0  11  307.0  0.0  ...
# 40772   1.0   90.0    6.0   5   1376.0     5.0  71.0   5  155.0  1.0  ...
# 40773   0.0    2.0   10.0  35   1424.0    46.0  17.0  42  190.0  0.0  ...
# 40774   1.0   22.0    1.0   1      0.0     0.0   1.0   1    8.0  1.0  ...
# 40775   0.0    7.0   27.0   3   1946.0    74.0   2.0   5    7.0  0.0  ...
#
#        V45  V47   V50  V51  V52   V59  V63  V72  V75  class
# ...

# %%
df.isnull().sum()
# Out:
# V1       0
# V2       0
# V3       0
# V4       0
# V5       0
# V6       0
# V7       0
# V8       0
# V9       0
# V10      0
# V11      0
# V13      0
# V19      0
# V22      0
# V30      0
# V33      0
# V35      0
# V36      0
# V40      0
# V41      0
# V42      0
# V43      0
# V45      0
# V47      0
# V50      0
# V51      0
# V52      0
# V59      0
# V63      0
# V72      0
# V75      0
# class    0
# dtype: int64

# %% [markdown]
# feature_columns = df.columns[:-1]

# %% [markdown]
# ### REMOVING OUTLIERS FROM THE DATASET

# %%
feature_columns = df.columns[df.columns != 'class']
filtered_df = df[(np.abs(zscore(df[feature_columns])) < 5).all(axis=1)]

# %%
filtered_df
# Out:
#          V1     V2     V3  V4      V5     V6    V7  V8     V9  V10  ...  V45  \
# 0       0.0    1.0  243.0  29  4528.0  138.0   3.0  29  201.0  0.0  ...    2
# 1       0.0   20.0    8.0  14  4183.0  183.0   4.0  26  156.0  0.0  ...    5
# 2      14.0    2.0    2.0   9  1113.0   15.0  37.0  31   78.0  1.0  ...    7
# 3       0.0  175.0   17.0  16  4250.0   68.0   8.0  30  152.0  0.0  ...    1
# 4       2.0   -1.0    1.0   3     0.0    0.0   2.0   5    6.0  1.0  ...    1
# ...     ...    ...    ...  ..     ...    ...   ...  ..    ...  ...  ...  ...
# 40770   0.0   12.0    3.0   6  1588.0   64.0   7.0  21   67.0  0.0  ...    0
# 40772   1.0   90.0    6.0   5  1376.0    5.0  71.0   5  155.0  1.0  ...    1
# 40773   0.0    2.0   10.0  35  1424.0   46.0  17.0  42  190.0  0.0  ...    1
# 40774   1.0   22.0    1.0   1     0.0    0.0   1.0   1    8.0  1.0  ...    8
# 40775   0.0    7.0   27.0   3  1946.0   74.0   2.0   5    7.0  0.0  ...    1
#
# ...

# %%
y=filtered_df["class"]
x=filtered_df.iloc[:,:-1]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
scaler=preprocessing.StandardScaler()

# %%
x_train=scaler.fit_transform(x_train)

# %%
x_train=pd.DataFrame(x_train,columns=x.columns)

# %%
lg=LogisticRegression()

# %%
lg.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=lg.predict(x_test)

# %%
df.columns
# Out:
# Index(['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11',
#        'V13', 'V19', 'V22', 'V30', 'V33', 'V35', 'V36', 'V40', 'V41', 'V42',
#        'V43', 'V45', 'V47', 'V50', 'V51', 'V52', 'V59', 'V63', 'V72', 'V75',
#        'class'],
#       dtype='object')

# %%
f1_score(y_test,y_pred)
# Out:
# 0.6752975569012319

# %%
test=pd.read_csv('Test.csv')

# %%
Index=test['Index']
test.drop(['Index'],axis=1,inplace=True)

# %%
test
# Out:
#          V1     V2    V3  V4      V5     V6    V7  V8     V9  V10  ...  \
# 0       3.0   97.0   2.0   3   475.0   23.0  11.0  10  146.0  1.0  ...
# 1       7.0   29.0  11.0  10     8.0    2.0  11.0  16   19.0  2.0  ...
# 2       2.0    9.0   5.0   1  1003.0   29.0   2.0  29   54.0  1.0  ...
# 3       0.0    0.0  22.0  17  1527.0   28.0   4.0  24   28.0  0.0  ...
# 4      13.0   -1.0  46.0   6     4.0    5.0  16.0  15   22.0  1.0  ...
# ...     ...    ...   ...  ..     ...    ...   ...  ..    ...  ...  ...
# 17471   5.0    8.0   2.0  17  1025.0  114.0   5.0  17   49.0  1.0  ...
# 17472   1.0   22.0   4.0  10     1.0    7.0   7.0  10   50.0  1.0  ...
# 17473   2.0   66.0   4.0   6  1025.0   38.0   2.0  38   38.0  1.0  ...
# 17474   1.0  944.0   6.0   6  1084.0    6.0  14.0  23   68.0  1.0  ...
# 17475   2.0  100.0   9.0   1     1.0    0.0   2.0   1    1.0  1.0  ...
#
#           V43  V45  V47   V50  V51  V52   V59  V63  V72  V75
# ...

# %%
result=lg.predict(test)

# %%
result
# Out:
# array([1, 0, 1, ..., 1, 1, 0], dtype=int64)

# %%
result = pd.DataFrame({
    'Index': Index,
    'class': result
})

# %%
result
# Out:
#        Index  class
# 0      40977      1
# 1      24157      0
# 2      56238      1
# 3      55411      1
# 4      53175      1
# ...      ...    ...
# 17471  17197      1
# 17472  14094      0
# 17473  34598      1
# 17474  17845      1
# 17475  11574      0
#
# [17476 rows x 2 columns]

# %%
result.to_csv("submission388.csv", index=False)
